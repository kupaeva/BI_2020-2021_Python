# %%
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw, ImageFilter

# %%
path = 'D:/YandexDisk/IB/python/graphical/test.jpg'

# %%
img = plt.imread(path)

# %%
original = img
plt.imshow(original)
plt.axis('off')
plt.show()

# %%
filter1 = img
plt.imshow(filter2.mean(2),cmap='cool')
plt.axis('off')
plt.show()

# %%
print(img.mean(2).shape)
# Out:
# (1080, 1920)

# %%
filter2 = img
plt.imshow(filter3[300:500, 900:1100])
plt.axis('off')
plt.show()

# %%
image = Image.open(path)
filter3 = image
filter3 = filter4.filter(ImageFilter.CONTOUR)
filter3.show()

# %%
filter4 = image
draw = ImageDraw.Draw(filter5)  
width = filter4.size[0]
height = filter4.size[1]
pix = filter4.load()

for x in range(width):
    for y in range(height):
        r = pix[x, y][0]
        g = pix[x, y][1]
        b = pix[x, y][2]
        draw.point((x, y), (255 - r, 255 - g, 255 - b))

filter4.show()

# %%
filter5 = image
draw = ImageDraw.Draw(filter5)  
pix = filter5.load()

for x in range(width):
    for y in range(height):
        r = pix[x, y][0]
        g = pix[x, y][1]
        b = pix[x, y][2]
        if r > 100 and g > 150 and  b > 150:
            draw.point((x, y), (255, 0, 0))
        else: 
            draw.point((x, y), (r, g, b))
            
filter5.show()
